# %% [raw]
# # 🛠️ Environment Setup for MCP Development
#
# Welcome to your MCP development environment setup! This notebook will guide you through installing all the necessary tools and dependencies to start building MCP servers and clients.
#
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will have:
# - A fully configured Python environment for MCP development
# - All necessary dependencies installed
# - Your first MCP development workspace ready
# - Understanding of the MCP development workflow
#
# ## 📋 Prerequisites
#
# - Python 3.8 or higher installed
# - Basic command line knowledge
# - Text editor or IDE (VS Code recommended)
#
# ## 📚 Table of Contents
#
# 1. [Python Environment Setup](#python-environment)
# 2. [Installing MCP Dependencies](#mcp-dependencies)
# 3. [Development Tools](#development-tools)
# 4. [Verifying Installation](#verification)
# 5. [Your First MCP Workspace](#workspace)
# 6. [Next Steps](#next-steps)
#
# ---

# %%
# Let's start by checking your current Python environment
import sys
import platform
import subprocess

print("🐍 Python Environment Check")
print("=" * 40)
print(f"Python Version: {sys.version}")
print(f"Platform: {platform.platform()}")
print(f"Architecture: {platform.architecture()[0]}")
print(f"Python Executable: {sys.executable}")
print()

# Check if we're in a virtual environment
in_venv = hasattr(sys, 'real_prefix') or (hasattr(sys, 'base_prefix') and sys.base_prefix != sys.prefix)
print(f"Virtual Environment: {'✅ Active' if in_venv else '❌ Not active'}")

if not in_venv:
    print("⚠️  RECOMMENDATION: Use a virtual environment for MCP development!")
    print("   This keeps your MCP dependencies separate from your system Python.")

print()
print("📦 Checking for pip...")
try:
    import pip
    print(f"✅ pip version: {pip.__version__}")
except ImportError:
    print("❌ pip not found - please install pip first!")

# Check Python version compatibility
major, minor = sys.version_info[:2]
if major >= 3 and minor >= 8:
    print(f"✅ Python {major}.{minor} is compatible with MCP")
else:
    print(f"❌ Python {major}.{minor} is too old - MCP requires Python 3.8+")
    print("   Please upgrade your Python installation.")

# %% [raw]
# ## 🏠 Setting Up Your Virtual Environment
#
# A **virtual environment** is essential for MCP development. It isolates your project dependencies and prevents conflicts with other Python projects.
#
# ### Creating a Virtual Environment
#
# If you don't have a virtual environment active, here's how to create one:
#
# ```bash
# # Create a new virtual environment
# python -m venv mcp_dev_env
#
# # Activate it (Linux/Mac)
# source mcp_dev_env/bin/activate
#
# # Activate it (Windows)
# mcp_dev_env\Scripts\activate
#
# # Your prompt should now show (mcp_dev_env)
# ```
#
# ### Why Use Virtual Environments?
#
# - **🔒 Isolation**: Keep MCP dependencies separate from system Python
# - **🧹 Clean**: Easy to delete and recreate if something goes wrong
# - **📦 Reproducible**: Same dependencies across different machines
# - **🚀 Professional**: Industry standard practice for Python development

# %%
# Let's install the core MCP dependencies
# NOTE: In a real environment, you'd run these commands in your terminal

install_commands = [
    "pip install --upgrade pip",
    "pip install mcp>=1.0.0",
    "pip install uvicorn>=0.24.0", 
    "pip install fastapi>=0.104.0",
    "pip install pydantic>=2.5.0",
    "pip install httpx>=0.25.0"
]

print("📦 Core MCP Dependencies Installation")
print("=" * 50)
print()
print("Run these commands in your terminal (with virtual environment active):")
print()

for i, cmd in enumerate(install_commands, 1):
    print(f"{i}. {cmd}")

print()
print("💡 Pro tip: You can also install all at once:")
print("   pip install mcp uvicorn fastapi pydantic httpx")
print()

# Let's try to import MCP to see if it's available
print("🔍 Checking if MCP is already installed...")
try:
    import mcp
    print(f"✅ MCP is installed! Version: {mcp.__version__ if hasattr(mcp, '__version__') else 'Unknown'}")
except ImportError:
    print("❌ MCP not found - you'll need to install it following the commands above")
    
try:
    import fastapi
    print(f"✅ FastAPI is available! Version: {fastapi.__version__}")
except ImportError:
    print("❌ FastAPI not found - needed for HTTP-based MCP servers")

try:
    import uvicorn
    print("✅ Uvicorn is available! (ASGI server for running MCP servers)")
except ImportError:
    print("❌ Uvicorn not found - needed for running MCP servers")
